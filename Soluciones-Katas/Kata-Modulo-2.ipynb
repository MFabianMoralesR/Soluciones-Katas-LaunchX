# %% [markdown]
# ## Crear u nentorno virtual

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('images\Creaentornovirtual.PNG'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1196x684 at 0x218F1264F10>

# %% [markdown]
# ## Activar entorno virtual

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('images\Activarentornovirtual.PNG'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=753x390 at 0x218F1DF8AC0>

# %% [markdown]
# ## Instalar una biblioteca

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('images\pipfreeze.PNG'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=780x388 at 0x218EF2569B0>

# %% [markdown]
# Instalacion datetuil

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('images\Instalaciondatetuil.PNG'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=775x387 at 0x218F1DF8A30>

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('images\pipfreeze2.PNG'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=783x387 at 0x218F1DF8F40>

# %% [markdown]
# ## Desactivar entorno virtual

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('images\deactivate.PNG'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=778x386 at 0x218F1DF83A0>
